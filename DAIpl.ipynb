# %% [markdown]
# ## Data Analysis of IPL-Matches(2008-2022)
# As you all know Cricket is a sport played and watched by millions of  people around the world but Indians are mad about cricket. Cricket is played in our streets. We like it so much. People in india are crazy about the game. Cricket is a Gentlemen Game , As a cricket lover, I decided to analyze the data of IPL matches. Why IPL match? Because cricket is not a game of any specific country or a nation, I love Indian league IPL .So, that why I shall anlyze the data of IPL matches from 2008 to 2022.
#
# * I found IPL matches (2008-2022) dataset from kaggle.
# * Here is the link of IPL matches Dataset: https://www.kaggle.com/datasets/vora1011/ipl-2008-to-2021-all-match-dataset?select=IPL_Matches_2008_2022.csv

# %% [markdown]
# ## Data Selection and Installing
# First we will select appropriate dataset from kaggle which I have done. You can check it at this link: https://www.kaggle.com/datasets/vora1011/ipl-2008-to-2021-all-match-dataset?select=IPL_Matches_2008_2022.csv. To download our dataset we have to install open dataset library by pip install command.

# %% [markdown]
# ###  Essential Libraries for this Project
# Lets import essential libraries for this project

# %%
! pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\darsh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\darsh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\darsh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\darsh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (4.39.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\darsh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\darsh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\darsh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\darsh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\darsh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\darsh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\darsh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: C:\Users\darsh\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# settings
sns.set_style('darkgrid')
# matplotlib.rcParams['font.size'] = 14
# matplotlib.rcParams['figure.figsize'] = (9, 5)
# lotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
import warnings   # to igonore warnings so that warnings will not be displayed in o/p cell
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Analysing IPl Match Dataset

# %% [markdown]
# ## Data Preparation and Cleaning
# First, we load our dataset into DataFrame and see our DataFrames first and last rows to overview of dataset

# %%
df = pd.read_csv('IPL_Matches_2008_2022.csv')

# %%
df.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# 3             Eden Gardens, Kolkata        Gujarat Titans        field
# 4          Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# 2         N  Royal Challengers Bangalore     Runs    14.0    NaN
# 3         N               Gujarat Titans  Wickets     7.0    NaN
# 4         N                 Punjab Kings  Wickets     5.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
#
#                                         Team2Players        Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2  ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4  ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
#
#          Umpire2
# 0    Nitin Menon
# 1    Nitin Menon
# 2       MA Gough
# 3      VK Sharma
# 4  NA Patwardhan

# %%
df.tail()
# Out:
#          ID        City        Date   Season MatchNumber  \
# 945  335986     Kolkata  2008-04-20  2007/08           4
# 946  335985      Mumbai  2008-04-20  2007/08           5
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                        Team2  \
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# 947                            Feroz Shah Kotla             Rajasthan Royals
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision SuperOver                  WinningTeam    WonBy  Margin  \
# 945          bat         N        Kolkata Knight Riders  Wickets     5.0
# 946          bat         N  Royal Challengers Bangalore  Wickets     5.0
# 947          bat         N             Delhi Daredevils  Wickets     9.0
# 948          bat         N          Chennai Super Kings     Runs    33.0
# 949        field         N        Kolkata Knight Riders     Runs   140.0
#
#     method Player_of_Match                                       Team1Players  \
# 945    NaN       DJ Hussey  ['WP Saha', 'BB McCullum', 'RT Ponting', 'SC G...
# 946    NaN      MV Boucher  ['L Ronchi', 'ST Jayasuriya', 'DJ Thornely', '...
# 947    NaN     MF Maharoof  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'MK Tiwa...
# 948    NaN      MEK Hussey  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# 949    NaN     BB McCullum  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                           Team2Players    Umpire1  \
# 945  ['AC Gilchrist', 'Y Venugopal Rao', 'VVS Laxma...  BF Bowden
# 946  ['S Chanderpaul', 'R Dravid', 'LRPL Taylor', '...   SJ Davis
# 947  ['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif'...  Aleem Dar
# 948  ['PA Patel', 'ML Hayden', 'MEK Hussey', 'MS Dh...  MR Benson
# 949  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...  Asad Rauf
#
#             Umpire2
# 945     K Hariharan
# 946       DJ Harper
# 947  GA Pratapkumar
# 948      SL Shastri
# 949     RE Koertzen

# %%
df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %% [markdown]
# By looking at the dataset we can see that our dataset contains many rows and columns. The dataset includes **MatchNumber**, **Team1**, **Team2**, **Venue**, **Team1Players**, **Team2Players**, **Umpire1** and **Umpire2** Data which gives us information about where match held, which teams played a match and about team players, about umpires also and information about **winning team** and win stats.

# %%
df.shape
# Out:
# (950, 20)

# %% [markdown]
# > 950 - rows & 20-cols in ipl match dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
#  16  Team1Players     950 non-null    object
#  17  Team2Players     950 non-null    object
#  18  Umpire1          950 non-null    object
#  19  Umpire2          950 non-null    object
# dtypes: float64(1), int64(1), object(18)
# memory usage: 148.6+ KB

# %%
# Cols which conatins null value 
# City ,SuperOver ,WinningTeam,Margin,method,Player_of_Match

# %%
df.describe()['Margin']
# Out:
# count    932.000000
# mean      17.056867
# std       21.633109
# min        1.000000
# 25%        6.000000
# 50%        8.000000
# 75%       19.000000
# max      146.000000
# Name: Margin, dtype: float64

# %% [markdown]
# > I cant say about mean ,median and other statistical values > bcoz margin is depended on wonby col(runs,wickets,superover,noresult)

# %%
df.nunique()
# Out:
# ID                 950
# City                33
# Date               706
# Season              15
# MatchNumber         80
# Team1               18
# Team2               18
# Venue               49
# TossWinner          18
# TossDecision         2
# SuperOver            2
# WinningTeam         18
# WonBy                4
# Margin              94
# method               1
# Player_of_Match    262
# Team1Players       932
# Team2Players       937
# Umpire1             58
# Umpire2             60
# dtype: int64

# %% [markdown]
# #### The above table provides us with very useful information. By above table we can see that as of 2022, there have been 15 seasons of IPL tournament hosted by 33 cities. Although, 9  teams have played and 262 Players become player of match in past seasons of IPL.

# %%
print("Total Null Cells ",df.isnull().sum().sum())
df.isnull().sum()
# Out:
# Total Null Cells  1012
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
df['Date'].dtype # date and time dtype
# Out:
# dtype('O')

# %% [markdown]
# In our DataFrame the date should be a string that represent date for future work with date. Let's convert all cells in **Date** column to dates. Pandas have **datetime()** method for this.

# %%
df['Date']=pd.to_datetime(df['Date']) # obj => Date Time

# %%
df['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['Date'][0]
# Out:
# Timestamp('2022-05-29 00:00:00')

# %% [markdown]
# Now, we will clean empty cells, wrong data and unusual data. We will also check any duplicate data in our dataset.

# %%
# Checking duplicate rows
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# > There are no duplicates within the dataset

# %%
df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
len(df.value_counts())
# Out:
# 19

# %%
df['City'].value_counts().sort_index()
# Out:
# Abu Dhabi          37
# Ahmedabad          19
# Bangalore          65
# Bengaluru          15
# Bloemfontein        2
# Cape Town           7
# Centurion          12
# Chandigarh         56
# Chennai            67
# Cuttack             7
# Delhi              78
# Dharamsala          9
# Dubai              13
# Durban             15
# East London         3
# Hyderabad          64
# Indore              9
# Jaipur             47
# Johannesburg        8
# Kanpur              4
# Kimberley           3
# Kochi               5
# Kolkata            79
# Mumbai            159
# Nagpur              3
# Navi Mumbai         9
# Port Elizabeth      7
# Pune               51
# Raipur              6
# Rajkot             10
# Ranchi              7
# Sharjah            10
# Visakhapatnam      13
# Name: City, dtype: int64

# %%
df['City']=df['City'].replace('Bengaluru','Bangalore')

# %%
df['City'].value_counts().sort_index()
# Out:
# Abu Dhabi          37
# Ahmedabad          19
# Bangalore          80
# Bloemfontein        2
# Cape Town           7
# Centurion          12
# Chandigarh         56
# Chennai            67
# Cuttack             7
# Delhi              78
# Dharamsala          9
# Dubai              13
# Durban             15
# East London         3
# Hyderabad          64
# Indore              9
# Jaipur             47
# Johannesburg        8
# Kanpur              4
# Kimberley           3
# Kochi               5
# Kolkata            79
# Mumbai            159
# Nagpur              3
# Navi Mumbai         9
# Port Elizabeth      7
# Pune               51
# Raipur              6
# Rajkot             10
# Ranchi              7
# Sharjah            10
# Visakhapatnam      13
# Name: City, dtype: int64

# %%
df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
df['Team1'].value_counts()
# Out:
# Royal Challengers Bangalore    126
# Mumbai Indians                 112
# Chennai Super Kings            111
# Kolkata Knight Riders          105
# Kings XI Punjab                 92
# Rajasthan Royals                89
# Delhi Daredevils                85
# Sunrisers Hyderabad             69
# Deccan Chargers                 39
# Delhi Capitals                  29
# Pune Warriors                   23
# Punjab Kings                    18
# Gujarat Lions                   16
# Lucknow Super Giants             8
# Gujarat Titans                   7
# Rising Pune Supergiant           7
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Name: Team1, dtype: int64

# %% [markdown]
# Renaming Ipl Team Names

# %%
df['Team1']= df['Team1'].replace('Kings XI Punjab','Punjab Kings')

# %%
df['Team1'].value_counts()
# Out:
# Royal Challengers Bangalore    126
# Mumbai Indians                 112
# Chennai Super Kings            111
# Punjab Kings                   110
# Kolkata Knight Riders          105
# Rajasthan Royals                89
# Delhi Daredevils                85
# Sunrisers Hyderabad             69
# Deccan Chargers                 39
# Delhi Capitals                  29
# Pune Warriors                   23
# Gujarat Lions                   16
# Lucknow Super Giants             8
# Gujarat Titans                   7
# Rising Pune Supergiant           7
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Name: Team1, dtype: int64

# %%
df['Team2']= df['Team2'].replace('Kings XI Punjab','Punjab Kings')

# %%
df['WinningTeam'].value_counts()
# Out:
# Mumbai Indians                 131
# Chennai Super Kings            121
# Kolkata Knight Riders          114
# Royal Challengers Bangalore    109
# Rajasthan Royals                96
# Kings XI Punjab                 88
# Sunrisers Hyderabad             75
# Delhi Daredevils                67
# Delhi Capitals                  36
# Deccan Chargers                 29
# Gujarat Lions                   13
# Punjab Kings                    13
# Pune Warriors                   12
# Gujarat Titans                  12
# Rising Pune Supergiant          10
# Lucknow Super Giants             9
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: WinningTeam, dtype: int64

# %%
df['WinningTeam']=df['WinningTeam'].replace('Kings XI Punjab','Punjab Kings')

# %%
df['WinningTeam'].value_counts()
# Out:
# Mumbai Indians                 131
# Chennai Super Kings            121
# Kolkata Knight Riders          114
# Royal Challengers Bangalore    109
# Punjab Kings                   101
# Rajasthan Royals                96
# Sunrisers Hyderabad             75
# Delhi Daredevils                67
# Delhi Capitals                  36
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Gujarat Titans                  12
# Rising Pune Supergiant          10
# Lucknow Super Giants             9
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: WinningTeam, dtype: int64

# %%
df['TossWinner']=df['TossWinner'].replace('Kings XI Punjab','Punjab Kings')

# %%
df.TossWinner.value_counts()
# Out:
# Mumbai Indians                 123
# Kolkata Knight Riders          114
# Chennai Super Kings            109
# Royal Challengers Bangalore    105
# Rajasthan Royals                99
# Punjab Kings                    94
# Delhi Daredevils                80
# Sunrisers Hyderabad             74
# Deccan Chargers                 43
# Delhi Capitals                  36
# Pune Warriors                   20
# Gujarat Lions                   15
# Gujarat Titans                  10
# Kochi Tuskers Kerala             8
# Lucknow Super Giants             7
# Rising Pune Supergiants          7
# Rising Pune Supergiant           6
# Name: TossWinner, dtype: int64

# %%
df['Team1']=df['Team1'].replace('Delhi Daredevils','Delhi Capitals')
df['Team2']=df['Team2'].replace('Delhi Daredevils','Delhi Capitals')
df['WinningTeam']=df['WinningTeam'].replace('Delhi Daredevils','Delhi Capitals')

# %%
df['Team1']=df['Team1'].replace('Rising Pune Supergiants','Rising Pune Supergiant')
df['Team2']=df['Team2'].replace('Rising Pune Supergiants','Rising Pune Supergiant')
df['WinningTeam']=df['WinningTeam'].replace('Rising Pune Supergiants','Rising Pune Supergiant')

# %% [markdown]
# > Dealing with null values

# %%
df.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
# city 
c1=df['City'].isnull()
df[c1]['Venue'].value_counts()
#-----
# Out:
# Dubai International Cricket Stadium    33
# Sharjah Cricket Stadium                18
# Name: Venue, dtype: int64

# %%
#vf = (df['Venue']==Dubai International Cricket Stadium) # city = Dubai


vf = (df['Venue'] =='Dubai International Cricket Stadium')
df.loc[vf,"City"] = 'Dubai'

# %%
vf1 = (df['Venue'] == 'Sharjah Cricket Stadium')

# %%
df.loc[vf1,'City'] = 'Sharjah'

# %%
df.isnull().sum()
# Out:
# ID                   0
# City                 0
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
df['SuperOver'].fillna('NoResult',inplace=True)
df['WinningTeam'].fillna('NoResult',inplace=True)
df['Player_of_Match'].fillna('NoResult',inplace= True)
df['Margin'].fillna('NoMargin',inplace = True)

# %%
df.isnull().sum()
# Out:
# ID                   0
# City                 0
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            0
# WinningTeam          0
# WonBy                0
# Margin               0
# method             931
# Player_of_Match      0
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
df.drop(columns=['method'],inplace=True)

# %%
df.head()
# Out:
#         ID       City       Date Season  MatchNumber  \
# 0  1312200  Ahmedabad 2022-05-29   2022        Final
# 1  1312199  Ahmedabad 2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata 2022-05-25   2022   Eliminator
# 3  1312197    Kolkata 2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai 2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# 3             Eden Gardens, Kolkata        Gujarat Titans        field
# 4          Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat
#
#   SuperOver                  WinningTeam    WonBy Margin Player_of_Match  \
# 0         N               Gujarat Titans  Wickets    7.0       HH Pandya
# 1         N             Rajasthan Royals  Wickets    7.0      JC Buttler
# 2         N  Royal Challengers Bangalore     Runs   14.0      RM Patidar
# 3         N               Gujarat Titans  Wickets    7.0       DA Miller
# 4         N                 Punjab Kings  Wickets    5.0   Harpreet Brar
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
#
#                                         Team2Players        Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2  ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4  ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
#
#          Umpire2
# 0    Nitin Menon
# 1    Nitin Menon
# 2       MA Gough
# 3      VK Sharma
# 4  NA Patwardhan

# %% [markdown]
# > Data has been Cleaned for further Processing

# %%
dfb = pd.read_csv('IPL_Ball_by_Ball_2008_2022.csv')
dfb.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# 0                 0        NaN  NaN               NaN  Rajasthan Royals
# 1                 0        NaN  NaN               NaN  Rajasthan Royals
# 2                 0        NaN  NaN               NaN  Rajasthan Royals
# 3                 0        NaN  NaN               NaN  Rajasthan Royals
# 4                 0        NaN  NaN               NaN  Rajasthan Royals

# %%
dfb.shape
# Out:
# (225954, 17)

# %% [markdown]
# > In our dataset we have 225954-rows and  17-columns

# %%
dfb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225954 entries, 0 to 225953
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ID                 225954 non-null  int64
#  1   innings            225954 non-null  int64
#  2   overs              225954 non-null  int64
#  3   ballnumber         225954 non-null  int64
#  4   batter             225954 non-null  object
#  5   bowler             225954 non-null  object
#  6   non-striker        225954 non-null  object
#  7   extra_type         12049 non-null   object
#  8   batsman_run        225954 non-null  int64
#  9   extras_run         225954 non-null  int64
#  10  total_run          225954 non-null  int64
#  11  non_boundary       225954 non-null  int64
#  12  isWicketDelivery   225954 non-null  int64
#  13  player_out         11151 non-null   object
#  14  kind               11151 non-null   object
#  15  fielders_involved  7988 non-null    object
#  16  BattingTeam        225954 non-null  object
# dtypes: int64(9), object(8)
# memory usage: 29.3+ MB

# %%
# checking duplicates 

dfb.duplicated().sum()
# Out:
# 0

# %% [markdown]
# > There are no duplicate values

# %%
## null value checking 
dfb.isnull().sum()
# Out:
# ID                        0
# innings                   0
# overs                     0
# ballnumber                0
# batter                    0
# bowler                    0
# non-striker               0
# extra_type           213905
# batsman_run               0
# extras_run                0
# total_run                 0
# non_boundary              0
# isWicketDelivery          0
# player_out           214803
# kind                 214803
# fielders_involved    217966
# BattingTeam               0
# dtype: int64

# %%
dfb.drop(columns=['extra_type','player_out','kind','fielders_involved'],inplace=True)

# %%
dfb.isnull().sum()
# Out:
# ID                  0
# innings             0
# overs               0
# ballnumber          0
# batter              0
# bowler              0
# non-striker         0
# batsman_run         0
# extras_run          0
# total_run           0
# non_boundary        0
# isWicketDelivery    0
# BattingTeam         0
# dtype: int64

# %%
dfb.columns
# Out:
# Index(['ID', 'innings', 'overs', 'ballnumber', 'batter', 'bowler',
#        'non-striker', 'batsman_run', 'extras_run', 'total_run', 'non_boundary',
#        'isWicketDelivery', 'BattingTeam'],
#       dtype='object')

# %%
dfb.rename(columns={'innings':'Innings','overs':'Overs','ballnumber':'Ballnumber','batter':'Batter', 'bowler':'Bowler',
       'non-striker':'Non-striker', 'batsman_run':'Batsman_run', 'extras_run':'Extra_run', 'total_run':'Total_run', 'non_boundary':'Non_boundary',
       'isWicketDelivery':'IsWicketDelivery'},inplace=True)

# %%
dfb.columns
# Out:
# Index(['ID', 'Innings', 'Overs', 'Ballnumber', 'Batter', 'Bowler',
#        'Non-striker', 'Batsman_run', 'Extra_run', 'Total_run', 'Non_boundary',
#        'IsWicketDelivery', 'BattingTeam'],
#       dtype='object')

# %%
dfb.head()
# Out:
#         ID  Innings  Overs  Ballnumber       Batter          Bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    Non-striker  Batsman_run  Extra_run  Total_run  Non_boundary  \
# 0   JC Buttler            0          0          0             0
# 1   JC Buttler            0          1          1             0
# 2  YBK Jaiswal            1          0          1             0
# 3   JC Buttler            0          0          0             0
# 4   JC Buttler            0          0          0             0
#
#    IsWicketDelivery       BattingTeam
# 0                 0  Rajasthan Royals
# 1                 0  Rajasthan Royals
# 2                 0  Rajasthan Royals
# 3                 0  Rajasthan Royals
# 4                 0  Rajasthan Royals

# %%
## Check for null vlaues 

dfb.isnull().sum()
# Out:
# ID                  0
# Innings             0
# Overs               0
# Ballnumber          0
# Batter              0
# Bowler              0
# Non-striker         0
# Batsman_run         0
# Extra_run           0
# Total_run           0
# Non_boundary        0
# IsWicketDelivery    0
# BattingTeam         0
# dtype: int64

# %%
dfb.nunique()
# Out:
# ID                  950
# Innings               6
# Overs                20
# Ballnumber           10
# Batter              605
# Bowler              472
# Non-striker         595
# Batsman_run           7
# Extra_run             7
# Total_run             8
# Non_boundary          2
# IsWicketDelivery      2
# BattingTeam          18
# dtype: int64

# %%
dfb['BattingTeam'].value_counts().sort_index()
# Out:
# Chennai Super Kings            25128
# Deccan Chargers                 9034
# Delhi Capitals                  7587
# Delhi Daredevils               18786
# Gujarat Lions                   3566
# Gujarat Titans                  1971
# Kings XI Punjab                22646
# Kochi Tuskers Kerala            1582
# Kolkata Knight Riders          26192
# Lucknow Super Giants            1840
# Mumbai Indians                 27826
# Pune Warriors                   5443
# Punjab Kings                    3388
# Rajasthan Royals               22777
# Rising Pune Supergiant          1900
# Rising Pune Supergiants         1580
# Royal Challengers Bangalore    26512
# Sunrisers Hyderabad            18196
# Name: BattingTeam, dtype: int64

# %%
dfb.columns
# Out:
# Index(['ID', 'Innings', 'Overs', 'Ballnumber', 'Batter', 'Bowler',
#        'Non-striker', 'Batsman_run', 'Extra_run', 'Total_run', 'Non_boundary',
#        'IsWicketDelivery', 'BattingTeam'],
#       dtype='object')

# %%
dfb['BattingTeam']=dfb['BattingTeam'].replace('Kings XI Punjab','Punjab Kings')

# %%
dfb['BattingTeam']=dfb['BattingTeam'].replace('Delhi Daredevils','Delhi Capitals')

# %%
dfb['BattingTeam']=dfb['BattingTeam'].replace('Rising Pune Supergiants','Rising Pune Supergiant')

# %%
dfb['BattingTeam'].value_counts().sort_index()
# Out:
# Chennai Super Kings            25128
# Deccan Chargers                 9034
# Delhi Capitals                 26373
# Gujarat Lions                   3566
# Gujarat Titans                  1971
# Kochi Tuskers Kerala            1582
# Kolkata Knight Riders          26192
# Lucknow Super Giants            1840
# Mumbai Indians                 27826
# Pune Warriors                   5443
# Punjab Kings                   26034
# Rajasthan Royals               22777
# Rising Pune Supergiant          3480
# Royal Challengers Bangalore    26512
# Sunrisers Hyderabad            18196
# Name: BattingTeam, dtype: int64

# %%
dfb.head(10)
# Out:
#         ID  Innings  Overs  Ballnumber       Batter          Bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# 5  1312200        1      0           6  YBK Jaiswal  Mohammed Shami
# 6  1312200        1      1           1   JC Buttler      Yash Dayal
# 7  1312200        1      1           2   JC Buttler      Yash Dayal
# 8  1312200        1      1           3   JC Buttler      Yash Dayal
# 9  1312200        1      1           4   JC Buttler      Yash Dayal
#
#    Non-striker  Batsman_run  Extra_run  Total_run  Non_boundary  \
# 0   JC Buttler            0          0          0             0
# 1   JC Buttler            0          1          1             0
# 2  YBK Jaiswal            1          0          1             0
# 3   JC Buttler            0          0          0             0
# 4   JC Buttler            0          0          0             0
# 5   JC Buttler            0          0          0             0
# 6  YBK Jaiswal            0          0          0             0
# 7  YBK Jaiswal            0          0          0             0
# 8  YBK Jaiswal            4          0          4             0
# 9  YBK Jaiswal            0          0          0             0
#
#    IsWicketDelivery       BattingTeam
# 0                 0  Rajasthan Royals
# 1                 0  Rajasthan Royals
# 2                 0  Rajasthan Royals
# 3                 0  Rajasthan Royals
# 4                 0  Rajasthan Royals
# 5                 0  Rajasthan Royals
# 6                 0  Rajasthan Royals
# 7                 0  Rajasthan Royals
# 8                 0  Rajasthan Royals
# 9                 0  Rajasthan Royals

# %%
## unique values in Ballnumber 

dfb['Ballnumber'].value_counts().sort_index()
# Out:
# 1     36599
# 2     36507
# 3     36413
# 4     36322
# 5     36201
# 6     36083
# 7      6585
# 8      1055
# 9       171
# 10       18
# Name: Ballnumber, dtype: int64

# %%
dfb['Innings'].value_counts().sort_index()
# Out:
# 1    116883
# 2    108910
# 3        77
# 4        72
# 5         8
# 6         4
# Name: Innings, dtype: int64

# %%
dfb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225954 entries, 0 to 225953
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   ID                225954 non-null  int64
#  1   Innings           225954 non-null  int64
#  2   Overs             225954 non-null  int64
#  3   Ballnumber        225954 non-null  int64
#  4   Batter            225954 non-null  object
#  5   Bowler            225954 non-null  object
#  6   Non-striker       225954 non-null  object
#  7   Batsman_run       225954 non-null  int64
#  8   Extra_run         225954 non-null  int64
#  9   Total_run         225954 non-null  int64
#  10  Non_boundary      225954 non-null  int64
#  11  IsWicketDelivery  225954 non-null  int64
#  12  BattingTeam       225954 non-null  object
# dtypes: int64(9), object(4)
# memory usage: 22.4+ MB

# %%
dfb.columns
# Out:
# Index(['ID', 'Innings', 'Overs', 'Ballnumber', 'Batter', 'Bowler',
#        'Non-striker', 'Batsman_run', 'Extra_run', 'Total_run', 'Non_boundary',
#        'IsWicketDelivery', 'BattingTeam'],
#       dtype='object')

# %%
dfb['Overs'].value_counts()
# Out:
# 0     12085
# 1     11935
# 2     11803
# 3     11773
# 4     11766
# 5     11720
# 6     11671
# 7     11651
# 8     11608
# 9     11578
# 10    11507
# 11    11480
# 12    11452
# 13    11355
# 14    11259
# 15    11093
# 16    10961
# 17    10650
# 18    10001
# 19     8606
# Name: Overs, dtype: int64

# %%
dfb['Overs']=dfb['Overs'].apply(lambda x : x+1)  # operation i++ => i=i+1

# %%
dfb.describe()[['Overs','Ballnumber','Batsman_run','Extra_run','Total_run']]
# Out:
#                Overs     Ballnumber    Batsman_run      Extra_run  \
# count  225954.000000  225954.000000  225954.000000  225954.000000
# mean       10.185679       3.619750       1.243523       0.066907
# std         5.681797       1.810633       1.618166       0.341470
# min         1.000000       1.000000       0.000000       0.000000
# 25%         5.000000       2.000000       0.000000       0.000000
# 50%        10.000000       4.000000       1.000000       0.000000
# 75%        15.000000       5.000000       1.000000       0.000000
# max        20.000000      10.000000       6.000000       7.000000
#
#           Total_run
# count  225954.00000
# mean        1.31043
# std         1.60605
# min         0.00000
# 25%         0.00000
# 50%         1.00000
# 75%         1.00000
# max         7.00000

# %% [markdown]
# > Done with Data Cleaning and Statistical Information

# %% [markdown]
# # Exploratory Data Analysis
# Now we will analyze our IPL dataset containing information about macthes, venue and scoring of IPL 15 seasons 2008 to 2022.

# %% [markdown]
# ##### what are  the *total* teams played from 2008-2022 and I want list of teams?

# %%
print(df.shape)
dfb.shape
# Out:
# (950, 19)
# (225954, 13)

# %%
df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'Player_of_Match', 'Team1Players', 'Team2Players',
#        'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
teamsdf = pd.DataFrame(df['Team1'].value_counts().index)

# %%
teamsdf.rename(columns={0:'Teams'},inplace=True)

# %%
teamsdf
# Out:
#                           Teams
# 0   Royal Challengers Bangalore
# 1                Delhi Capitals
# 2                Mumbai Indians
# 3           Chennai Super Kings
# 4                  Punjab Kings
# 5         Kolkata Knight Riders
# 6              Rajasthan Royals
# 7           Sunrisers Hyderabad
# 8               Deccan Chargers
# 9                 Pune Warriors
# 10                Gujarat Lions
# 11       Rising Pune Supergiant
# 12         Lucknow Super Giants
# 13               Gujarat Titans
# 14         Kochi Tuskers Kerala

# %%
len(teamsdf)
# Out:
# 15

# %% [markdown]
# > There are total 15 Teams and in teamdf you can see the list of teams

# %% [markdown]
# ##### Total Matches Played By Each Team ?

# %%
df["Team1"]
# Out:
# 0                 Rajasthan Royals
# 1      Royal Challengers Bangalore
# 2      Royal Challengers Bangalore
# 3                 Rajasthan Royals
# 4              Sunrisers Hyderabad
#                   ...
# 945          Kolkata Knight Riders
# 946                 Mumbai Indians
# 947                 Delhi Capitals
# 948                   Punjab Kings
# 949    Royal Challengers Bangalore
# Name: Team1, Length: 950, dtype: object

# %%
teams_matches = pd.concat([df['Team1'],df['Team2']]).value_counts()
teams_matches = pd.DataFrame(teams_matches).reset_index()
teams_matches.rename(columns={'index':'Teams',0:'Total_Matches'},inplace=True)

# %%
teams_matches
# Out:
#                           Teams  Total_Matches
# 0                Mumbai Indians            231
# 1   Royal Challengers Bangalore            226
# 2                Delhi Capitals            224
# 3         Kolkata Knight Riders            223
# 4                  Punjab Kings            218
# 5           Chennai Super Kings            208
# 6              Rajasthan Royals            192
# 7           Sunrisers Hyderabad            152
# 8               Deccan Chargers             75
# 9                 Pune Warriors             46
# 10       Rising Pune Supergiant             30
# 11                Gujarat Lions             30
# 12               Gujarat Titans             16
# 13         Lucknow Super Giants             15
# 14         Kochi Tuskers Kerala             14

# %% [markdown]
# ## Visualization
#
# > Matplotlib

# %%
def get_color(name, number):
    pal = list(sns.color_palette(palette=name, n_colors=number).as_hex())
    return pal

# %%
pal_vi = get_color('viridis_r', len(df))
pal_vi
# Out:
# ['#fde725',
#  '#fde725',
#  '#fde725',
#  '#fbe723',
#  '#fbe723',
#  '#fbe723',
#  '#fbe723',
#  '#f8e621',
#  '#f8e621',
#  '#f8e621',
#  '#f8e621',
#  '#f6e620',
#  '#f6e620',
#  '#f6e620',
#  '#f4e61e',
#  '#f4e61e',
#  '#f4e61e',
#  '#f4e61e',
#  '#f1e51d',
#  '#f1e51d',
#  '#f1e51d',
#  '#f1e51d',
#  '#efe51c',
#  '#efe51c',
#  '#efe51c',
#  '#efe51c',
#  '#ece51b',
#  '#ece51b',
#  '#ece51b',
#  '#eae51a',
#  '#eae51a',
#  '#eae51a',
#  '#eae51a',
#  '#e7e419',
#  '#e7e419',
#  '#e7e419',
#  '#e7e419',
#  '#e5e419',
#  '#e5e419',
#  '#e5e419',
#  '#e2e418',
#  '#e2e418',
#  '#e2e418',
#  '#e2e418',
#  '#dfe318',
#  '#dfe318',
#  '#dfe318',
#  '#dfe318',
#  '#dde318',
#  '#dde318',
#  '#dde318',
#  '#dde318',
#  '#dae319',
#  '#dae319',
#  '#dae319',
#  '#d8e219',
#  '#d8e219',
#  '#d8e219',
#  '#d8e219',
#  '#d5e21a',
#  '#d5e21a',
#  '#d5e21a',
#  '#d5e21a',
#  '#d2e21b',
#  '#d2e21b',
#  '#d2e21b',
#  '#d0e11c',
#  '#d0e11c',
#  '#d0e11c',
#  '#d0e11c',
#  '#cde11d',
#  '#cde11d',
#  '#cde11d',
#  '#cde11d',
#  '#cae11f',
#  '#cae11f',
#  '#cae11f',
#  '#cae11f',
#  '#c8e020',
#  '#c8e020',
#  '#c8e020',
#  '#c5e021',
#  '#c5e021',
#  '#c5e021',
#  '#c5e021',
#  '#c2df23',
#  '#c2df23',
#  '#c2df23',
#  '#c2df23',
#  '#c0df25',
#  '#c0df25',
#  '#c0df25',
#  '#bddf26',
#  '#bddf26',
#  '#bddf26',
#  '#bddf26',
#  '#bade28',
#  '#bade28',
#  '#bade28',
#  '#bade28',
#  '#b8de29',
#  '#b8de29',
#  '#b8de29',
#  '#b8de29',
#  '#b5de2b',
#  '#b5de2b',
#  '#b5de2b',
#  '#b2dd2d',
#  '#b2dd2d',
#  '#b2dd2d',
#  '#b2dd2d',
#  '#b0dd2f',
#  '#b0dd2f',
#  '#b0dd2f',
#  '#b0dd2f',
#  '#addc30',
#  '#addc30',
#  '#addc30',
#  '#aadc32',
#  '#aadc32',
#  '#aadc32',
#  '#aadc32',
#  '#a8db34',
#  '#a8db34',
#  '#a8db34',
#  '#a8db34',
#  '#a5db36',
#  '#a5db36',
#  '#a5db36',
#  '#a5db36',
#  '#a2da37',
#  '#a2da37',
#  '#a2da37',
#  '#a0da39',
#  '#a0da39',
#  '#a0da39',
#  '#a0da39',
#  '#9dd93b',
#  '#9dd93b',
#  '#9dd93b',
#  '#9dd93b',
#  '#9bd93c',
#  '#9bd93c',
#  '#9bd93c',
#  '#98d83e',
#  '#98d83e',
#  '#98d83e',
#  '#98d83e',
#  '#95d840',
#  '#95d840',
#  '#95d840',
#  '#95d840',
#  '#93d741',
#  '#93d741',
#  '#93d741',
#  '#93d741',
#  '#90d743',
#  '#90d743',
#  '#90d743',
#  '#8ed645',
#  '#8ed645',
#  '#8ed645',
#  '#8ed645',
#  '#8bd646',
#  '#8bd646',
#  '#8bd646',
#  '#8bd646',
#  '#89d548',
#  '#89d548',
#  '#89d548',
#  '#86d549',
#  '#86d549',
#  '#86d549',
#  '#86d549',
#  '#84d44b',
#  '#84d44b',
#  '#84d44b',
#  '#84d44b',
#  '#81d34d',
#  '#81d34d',
#  '#81d34d',
#  '#81d34d',
#  '#7fd34e',
#  '#7fd34e',
#  '#7fd34e',
#  '#7cd250',
#  '#7cd250',
#  '#7cd250',
#  '#7cd250',
#  '#7ad151',
#  '#7ad151',
#  '#7ad151',
#  '#7ad151',
#  '#77d153',
#  '#77d153',
#  '#77d153',
#  '#75d054',
#  '#75d054',
#  '#75d054',
#  '#75d054',
#  '#73d056',
#  '#73d056',
#  '#73d056',
#  '#73d056',
#  '#70cf57',
#  '#70cf57',
#  '#70cf57',
#  '#70cf57',
#  '#6ece58',
#  '#6ece58',
#  '#6ece58',
#  '#6ccd5a',
#  '#6ccd5a',
#  '#6ccd5a',
#  '#6ccd5a',
#  '#69cd5b',
#  '#69cd5b',
#  '#69cd5b',
#  '#69cd5b',
#  '#67cc5c',
#  '#67cc5c',
#  '#67cc5c',
#  '#65cb5e',
#  '#65cb5e',
#  '#65cb5e',
#  '#65cb5e',
#  '#63cb5f',
#  '#63cb5f',
#  '#63cb5f',
#  '#63cb5f',
#  '#60ca60',
#  '#60ca60',
#  '#60ca60',
#  '#60ca60',
#  '#5ec962',
#  '#5ec962',
#  '#5ec962',
#  '#5cc863',
#  '#5cc863',
#  '#5cc863',
#  '#5cc863',
#  '#5ac864',
#  '#5ac864',
#  '#5ac864',
#  '#5ac864',
#  '#58c765',
#  '#58c765',
#  '#58c765',
#  '#56c667',
#  '#56c667',
#  '#56c667',
#  '#56c667',
#  '#54c568',
#  '#54c568',
#  '#54c568',
#  '#54c568',
#  '#52c569',
#  '#52c569',
#  '#52c569',
#  '#52c569',
#  '#50c46a',
#  '#50c46a',
#  '#50c46a',
#  '#4ec36b',
#  '#4ec36b',
#  '#4ec36b',
#  '#4ec36b',
#  '#4cc26c',
#  '#4cc26c',
#  '#4cc26c',
#  '#4cc26c',
#  '#4ac16d',
#  '#4ac16d',
#  '#4ac16d',
#  '#48c16e',
#  '#48c16e',
#  '#48c16e',
#  '#48c16e',
#  '#46c06f',
#  '#46c06f',
#  '#46c06f',
#  '#46c06f',
#  '#44bf70',
#  '#44bf70',
#  '#44bf70',
#  '#44bf70',
#  '#42be71',
#  '#42be71',
#  '#42be71',
#  '#40bd72',
#  '#40bd72',
#  '#40bd72',
#  '#40bd72',
#  '#3fbc73',
#  '#3fbc73',
#  '#3fbc73',
#  '#3fbc73',
#  '#3dbc74',
#  '#3dbc74',
#  '#3dbc74',
#  '#3bbb75',
#  '#3bbb75',
#  '#3bbb75',
#  '#3bbb75',
#  '#3aba76',
#  '#3aba76',
#  '#3aba76',
#  '#3aba76',
#  '#38b977',
#  '#38b977',
#  '#38b977',
#  '#38b977',
#  '#37b878',
#  '#37b878',
#  '#37b878',
#  '#35b779',
#  '#35b779',
#  '#35b779',
#  '#35b779',
#  '#34b679',
#  '#34b679',
#  '#34b679',
#  '#34b679',
#  '#32b67a',
#  '#32b67a',
#  '#32b67a',
#  '#31b57b',
#  '#31b57b',
#  '#31b57b',
#  '#31b57b',
#  '#2fb47c',
#  '#2fb47c',
#  '#2fb47c',
#  '#2fb47c',
#  '#2eb37c',
#  '#2eb37c',
#  '#2eb37c',
#  '#2eb37c',
#  '#2db27d',
#  '#2db27d',
#  '#2db27d',
#  '#2cb17e',
#  '#2cb17e',
#  '#2cb17e',
#  '#2cb17e',
#  '#2ab07f',
#  '#2ab07f',
#  '#2ab07f',
#  '#2ab07f',
#  '#29af7f',
#  '#29af7f',
#  '#29af7f',
#  '#28ae80',
#  '#28ae80',
#  '#28ae80',
#  '#28ae80',
#  '#27ad81',
#  '#27ad81',
#  '#27ad81',
#  '#27ad81',
#  '#26ad81',
#  '#26ad81',
#  '#26ad81',
#  '#26ad81',
#  '#25ac82',
#  '#25ac82',
#  '#25ac82',
#  '#25ab82',
#  '#25ab82',
#  '#25ab82',
#  '#25ab82',
#  '#24aa83',
#  '#24aa83',
#  '#24aa83',
#  '#24aa83',
#  '#23a983',
#  '#23a983',
#  '#23a983',
#  '#22a884',
#  '#22a884',
#  '#22a884',
#  '#22a884',
#  '#22a785',
#  '#22a785',
#  '#22a785',
#  '#22a785',
#  '#21a685',
#  '#21a685',
#  '#21a685',
#  '#21a685',
#  '#21a585',
#  '#21a585',
#  '#21a585',
#  '#20a486',
#  '#20a486',
#  '#20a486',
#  '#20a486',
#  '#20a386',
#  '#20a386',
#  '#20a386',
#  '#20a386',
#  '#1fa287',
#  '#1fa287',
#  '#1fa287',
#  '#1fa187',
#  '#1fa187',
#  '#1fa187',
#  '#1fa187',
#  '#1fa188',
#  '#1fa188',
#  '#1fa188',
#  '#1fa188',
#  '#1fa088',
#  '#1fa088',
#  '#1fa088',
#  '#1fa088',
#  '#1f9f88',
#  '#1f9f88',
#  '#1f9f88',
#  '#1f9e89',
#  '#1f9e89',
#  '#1f9e89',
#  '#1f9e89',
#  '#1e9d89',
#  '#1e9d89',
#  '#1e9d89',
#  '#1e9d89',
#  '#1e9c89',
#  '#1e9c89',
#  '#1e9c89',
#  '#1e9b8a',
#  '#1e9b8a',
#  '#1e9b8a',
#  '#1e9b8a',
#  '#1f9a8a',
#  '#1f9a8a',
#  '#1f9a8a',
#  '#1f9a8a',
#  '#1f998a',
#  '#1f998a',
#  '#1f998a',
#  '#1f998a',
#  '#1f988b',
#  '#1f988b',
#  '#1f988b',
#  '#1f978b',
#  '#1f978b',
#  '#1f978b',
#  '#1f978b',
#  '#1f968b',
#  '#1f968b',
#  '#1f968b',
#  '#1f968b',
#  '#1f958b',
#  '#1f958b',
#  '#1f958b',
#  '#1f948c',
#  '#1f948c',
#  '#1f948c',
#  '#1f948c',
#  '#20938c',
#  '#20938c',
#  '#20938c',
#  '#20938c',
#  '#20928c',
#  '#20928c',
#  '#20928c',
#  '#20928c',
#  '#20928c',
#  '#20928c',
#  '#20928c',
#  '#21918c',
#  '#21918c',
#  '#21918c',
#  '#21918c',
#  '#21908d',
#  '#21908d',
#  '#21908d',
#  '#21908d',
#  '#218f8d',
#  '#218f8d',
#  '#218f8d',
#  '#218e8d',
#  '#218e8d',
#  '#218e8d',
#  '#218e8d',
#  '#228d8d',
#  '#228d8d',
#  '#228d8d',
#  '#228d8d',
#  '#228c8d',
#  '#228c8d',
#  '#228c8d',
#  '#228c8d',
#  '#228b8d',
#  '#228b8d',
#  '#228b8d',
#  '#238a8d',
#  '#238a8d',
#  '#238a8d',
#  '#238a8d',
#  '#23898e',
#  '#23898e',
#  '#23898e',
#  '#23898e',
#  '#23888e',
#  '#23888e',
#  '#23888e',
#  '#24878e',
#  '#24878e',
#  '#24878e',
#  '#24878e',
#  '#24868e',
#  '#24868e',
#  '#24868e',
#  '#24868e',
#  '#25858e',
#  '#25858e',
#  '#25858e',
#  '#25858e',
#  '#25848e',
#  '#25848e',
#  '#25848e',
#  '#25838e',
#  '#25838e',
#  '#25838e',
#  '#25838e',
#  '#26828e',
#  '#26828e',
#  '#26828e',
#  '#26828e',
#  '#26828e',
#  '#26828e',
#  '#26828e',
#  '#26818e',
#  '#26818e',
#  '#26818e',
#  '#26818e',
#  '#27808e',
#  '#27808e',
#  '#27808e',
#  '#27808e',
#  '#277f8e',
#  '#277f8e',
#  '#277f8e',
#  '#277f8e',
#  '#277e8e',
#  '#277e8e',
#  '#277e8e',
#  '#287d8e',
#  '#287d8e',
#  '#287d8e',
#  '#287d8e',
#  '#287c8e',
#  '#287c8e',
#  '#287c8e',
#  '#287c8e',
#  '#297b8e',
#  '#297b8e',
#  '#297b8e',
#  '#297a8e',
#  '#297a8e',
#  '#297a8e',
#  '#297a8e',
#  '#29798e',
#  '#29798e',
#  '#29798e',
#  '#29798e',
#  '#2a788e',
#  '#2a788e',
#  '#2a788e',
#  '#2a788e',
#  '#2a778e',
#  '#2a778e',
#  '#2a778e',
#  '#2a768e',
#  '#2a768e',
#  '#2a768e',
#  '#2a768e',
#  '#2b758e',
#  '#2b758e',
#  '#2b758e',
#  '#2b758e',
#  '#2b748e',
#  '#2b748e',
#  '#2b748e',
#  '#2c738e',
#  '#2c738e',
#  '#2c738e',
#  '#2c738e',
#  '#2c728e',
#  '#2c728e',
#  '#2c728e',
#  '#2c728e',
#  '#2c718e',
#  '#2c718e',
#  '#2c718e',
#  '#2c718e',
#  '#2d718e',
#  '#2d718e',
#  '#2d718e',
#  '#2d708e',
#  '#2d708e',
#  '#2d708e',
#  '#2d708e',
#  '#2e6f8e',
#  '#2e6f8e',
#  '#2e6f8e',
#  '#2e6f8e',
#  '#2e6e8e',
#  '#2e6e8e',
#  '#2e6e8e',
#  '#2e6d8e',
#  '#2e6d8e',
#  '#2e6d8e',
#  '#2e6d8e',
#  '#2f6c8e',
#  '#2f6c8e',
#  '#2f6c8e',
#  '#2f6c8e',
#  '#2f6b8e',
#  '#2f6b8e',
#  '#2f6b8e',
#  '#2f6b8e',
#  '#306a8e',
#  '#306a8e',
#  '#306a8e',
#  '#30698e',
#  '#30698e',
#  '#30698e',
#  '#30698e',
#  '#31688e',
#  '#31688e',
#  '#31688e',
#  '#31688e',
#  '#31678e',
#  '#31678e',
#  '#31678e',
#  '#31668e',
#  '#31668e',
#  '#31668e',
#  '#31668e',
#  '#32658e',
#  '#32658e',
#  '#32658e',
#  '#32658e',
#  '#32648e',
#  '#32648e',
#  '#32648e',
#  '#32648e',
#  '#33638d',
#  '#33638d',
#  '#33638d',
#  '#33628d',
#  '#33628d',
#  '#33628d',
#  '#33628d',
#  '#34618d',
#  '#34618d',
#  '#34618d',
#  '#34618d',
#  '#34608d',
#  '#34608d',
#  '#34608d',
#  '#355f8d',
#  '#355f8d',
#  '#355f8d',
#  '#355f8d',
#  '#355e8d',
#  '#355e8d',
#  '#355e8d',
#  '#355e8d',
#  '#365d8d',
#  '#365d8d',
#  '#365d8d',
#  '#365d8d',
#  '#365c8d',
#  '#365c8d',
#  '#365c8d',
#  '#375b8d',
#  '#375b8d',
#  '#375b8d',
#  '#375b8d',
#  '#375a8c',
#  '#375a8c',
#  '#375a8c',
#  '#375a8c',
#  '#38598c',
#  '#38598c',
#  '#38598c',
#  '#38588c',
#  '#38588c',
#  '#38588c',
#  '#38588c',
#  '#39568c',
#  '#39568c',
#  '#39568c',
#  '#39568c',
#  '#39558c',
#  '#39558c',
#  '#39558c',
#  '#39558c',
#  '#3a548c',
#  '#3a548c',
#  '#3a548c',
#  '#3a538b',
#  '#3a538b',
#  '#3a538b',
#  '#3a538b',
#  '#3b528b',
#  '#3b528b',
#  '#3b528b',
#  '#3b528b',
#  '#3b518b',
#  '#3b518b',
#  '#3b518b',
#  '#3c508b',
#  '#3c508b',
#  '#3c508b',
#  '#3c508b',
#  '#3c4f8a',
#  '#3c4f8a',
#  '#3c4f8a',
#  '#3c4f8a',
#  '#3d4e8a',
#  '#3d4e8a',
#  '#3d4e8a',
#  '#3d4e8a',
#  '#3d4d8a',
#  '#3d4d8a',
#  '#3d4d8a',
#  '#3e4c8a',
#  '#3e4c8a',
#  '#3e4c8a',
#  '#3e4c8a',
#  '#3e4a89',
#  '#3e4a89',
#  '#3e4a89',
#  '#3e4a89',
#  '#3e4989',
#  '#3e4989',
#  '#3e4989',
#  '#3f4889',
#  '#3f4889',
#  '#3f4889',
#  '#3f4889',
#  '#3f4788',
#  '#3f4788',
#  '#3f4788',
#  '#3f4788',
#  '#404688',
#  '#404688',
#  '#404688',
#  '#404688',
#  '#404588',
#  '#404588',
#  '#404588',
#  '#414487',
#  '#414487',
#  '#414487',
#  '#414487',
#  '#414287',
#  '#414287',
#  '#414287',
#  '#414287',
#  '#424186',
#  '#424186',
#  '#424186',
#  '#424086',
#  '#424086',
#  '#424086',
#  '#424086',
#  '#423f85',
#  '#423f85',
#  '#423f85',
#  '#423f85',
#  '#433e85',
#  '#433e85',
#  '#433e85',
#  '#433e85',
#  '#433d84',
#  '#433d84',
#  '#433d84',
#  '#443b84',
#  '#443b84',
#  '#443b84',
#  '#443b84',
#  '#443a83',
#  '#443a83',
#  '#443a83',
#  '#443a83',
#  '#443983',
#  '#443983',
#  '#443983',
#  '#453882',
#  '#453882',
#  '#453882',
#  '#453882',
#  '#453781',
#  '#453781',
#  '#453781',
#  '#453781',
#  '#453581',
#  '#453581',
#  '#453581',
#  '#453581',
#  '#463480',
#  '#463480',
#  '#463480',
#  '#46337f',
#  '#46337f',
#  '#46337f',
#  '#46337f',
#  '#46327e',
#  '#46327e',
#  '#46327e',
#  '#46327e',
#  '#46307e',
#  '#46307e',
#  '#46307e',
#  '#472f7d',
#  '#472f7d',
#  '#472f7d',
#  '#472f7d',
#  '#472e7c',
#  '#472e7c',
#  '#472e7c',
#  '#472e7c',
#  '#472d7b',
#  '#472d7b',
#  '#472d7b',
#  '#472d7b',
#  '#472c7a',
#  '#472c7a',
#  '#472c7a',
#  '#472a7a',
#  '#472a7a',
#  '#472a7a',
#  '#472a7a',
#  '#482979',
#  '#482979',
#  '#482979',
#  '#482979',
#  '#482878',
#  '#482878',
#  '#482878',
#  '#482677',
#  '#482677',
#  '#482677',
#  '#482677',
#  '#482576',
#  '#482576',
#  '#482576',
#  '#482576',
#  '#482475',
#  '#482475',
#  '#482475',
#  '#482475',
#  '#482374',
#  '#482374',
#  '#482374',
#  '#482173',
#  '#482173',
#  '#482173',
#  '#482173',
#  '#482071',
#  '#482071',
#  '#482071',
#  '#482071',
#  '#481f70',
#  '#481f70',
#  '#481f70',
#  '#481d6f',
#  '#481d6f',
#  '#481d6f',
#  '#481d6f',
#  '#481c6e',
#  '#481c6e',
#  '#481c6e',
#  '#481c6e',
#  '#481b6d',
#  '#481b6d',
#  '#481b6d',
#  '#481b6d',
#  '#481a6c',
#  '#481a6c',
#  '#481a6c',
#  '#48186a',
#  '#48186a',
#  '#48186a',
#  '#48186a',
#  '#481769',
#  '#481769',
#  '#481769',
#  '#481769',
#  '#481668',
#  '#481668',
#  '#481668',
#  '#481467',
#  '#481467',
#  '#481467',
#  '#481467',
#  '#471365',
#  '#471365',
#  '#471365',
#  '#471365',
#  '#471164',
#  '#471164',
#  '#471164',
#  '#471164',
#  '#471063',
#  '#471063',
#  '#471063',
#  '#470e61',
#  '#470e61',
#  '#470e61',
#  '#470e61',
#  '#470d60',
#  '#470d60',
#  '#470d60',
#  '#470d60',
#  '#460b5e',
#  '#460b5e',
#  '#460b5e',
#  '#460a5d',
#  '#460a5d',
#  '#460a5d',
#  '#460a5d',
#  '#46085c',
#  '#46085c',
#  '#46085c',
#  '#46085c',
#  '#46075a',
#  '#46075a',
#  '#46075a',
#  '#46075a',
#  '#450559',
#  '#450559',
#  '#450559',
#  '#450457',
#  '#450457',
#  '#450457',
#  '#450457',
#  '#440256',
#  '#440256',
#  '#440256',
#  '#440256',
#  '#440154',
#  '#440154',
#  '#440154']

# %%
teams_matches.columns
# Out:
# Index(['Teams', 'Total_Matches'], dtype='object')

# %%
# Set figure size
plt.figure(figsize=(30, 10))

# Create bar plot
teams_matches1 = teams_matches.head(10)
bars = plt.bar(
    teams_matches1['Teams'],
    teams_matches1['Total_Matches'],
 # Use your color palette
)


plt.xlabel('Teams')
plt.ylabel('Total Matches')
for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        height,
        f'{height}',
        ha='center',
        va='bottom',
        fontsize=10
    )

# Customize plot appearance
plt.xlabel('Teams')
plt.xscale()
plt.ylabel('Total Matches')
plt.xticks(rotation=45)
plt.gca().set_facecolor('white')   # Plot background
plt.gcf().set_facecolor('white')   # Figure background

# Remove top and right spines for a cleaner look
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[173], line 28
#      26 # Customize plot appearance
#      27 plt.xlabel('Teams')
# ---> 28 plt.xscale()
#      29 plt.ylabel('Total Matches')
#      30 plt.xticks(rotation=45)
#
# TypeError: xscale() missing 1 required positional argument: 'value'

# %%
teams_matches.columns
# Out:
# Index(['Teams', 'Total_Matches'], dtype='object')

# %%
list(teams_matches['Teams'])
# Out:
# ['Mumbai Indians',
#  'Royal Challengers Bangalore',
#  'Delhi Capitals',
#  'Kolkata Knight Riders',
#  'Punjab Kings',
#  'Chennai Super Kings',
#  'Rajasthan Royals',
#  'Sunrisers Hyderabad',
#  'Deccan Chargers',
#  'Pune Warriors',
#  'Rising Pune Supergiant',
#  'Gujarat Lions',
#  'Gujarat Titans',
#  'Lucknow Super Giants',
#  'Kochi Tuskers Kerala']

# %%
team_mapping = {
    'Mumbai Indians': 'MI',
    'Royal Challengers Bangalore': 'RCB',
    'Delhi Capitals': 'DC',
    'Kolkata Knight Riders': 'KKR',
    'Punjab Kings': 'PBKS',
    'Chennai Super Kings': 'CSK',
    'Rajasthan Royals': 'RR',
    'Sunrisers Hyderabad': 'SRH',
    'Deccan Chargers': 'DCH',
    'Pune Warriors': 'PW',
    'Rising Pune Supergiant': 'RPS',
    'Gujarat Lions': 'GL',
    'Gujarat Titans': 'GT',
    'Lucknow Super Giants': 'LSG',
    'Kochi Tuskers Kerala': 'KTK'
}

teams_matches.replace(team_mapping, inplace=True)

# %%
teams_matches
# Out:
#    Teams  Total_Matches
# 0     MI            231
# 1    RCB            226
# 2     DC            224
# 3    KKR            223
# 4   PBKS            218
# 5    CSK            208
# 6     RR            192
# 7    SRH            152
# 8    DCG             75
# 9     PW             46
# 10   RPS             30
# 11    GL             30
# 12    GT             16
# 13   LSG             15
# 14   KTK             14

# %%
sns.set(rc={'figure.figsize':(20,10)})

# %%
ax= sns.barplot(teams_matches,x='Teams',y='Total_Matches')
for bar in ax.containers:
    ax.bar_label(bar)

plt.show()

# %% [markdown]
# Plotly Python is an interactive, browser-based graphing library powered by the JavaScript library plotly.js. The core theory revolves around treating all visualizations as serialized JSON data structures. This allows for native interactivity (zooming, panning) and seamless embedding in web apps

# %%
! pip install plotly --upgrade --quiet
# Out:
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: C:\Users\darsh\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
teams_matches
# Out:
#    Teams  Total_Matches
# 0     MI            231
# 1    RCB            226
# 2     DC            224
# 3    KKR            223
# 4   PBKS            218
# 5    CSK            208
# 6     RR            192
# 7    SRH            152
# 8    DCG             75
# 9     PW             46
# 10   RPS             30
# 11    GL             30
# 12    GT             16
# 13   LSG             15
# 14   KTK             14

# %%
import plotly.express as px
fig = px.bar(teams_matches, x='Teams', y='Total_Matches', text='Total_Matches',
             color ='Teams')

fig.update_traces(texttemplate='%{text:.3s}', textposition='outside')
fig.update_layout({'plot_bgcolor': 'white',
                   'paper_bgcolor': 'white'})

fig.update_layout(width=1100, height=500,
                  margin = dict(t=15, l=15, r=15, b=15))
fig.show()

# %% [markdown]
# By above analysis we can see that number of matches played by Mumbai indians, Royal Challengers Bangalore, Delhi Capitals, Kolkata Knight Riders, Punjab Kings, Chennai Super Kings is high. On the other hand, Kochi Tuskers Kerala, Pune Warriors, Gujarat Lions, Deccan Charges ,Rising Pune Supergiant are the defunct team by BCCI.

# %% [markdown]
# #### Winning Ratio Analysis

# %%
teams_matches.drop(columns=['total_wins','win_ratio'],inplace=True)

# %%
teams_matches
# Out:
#    Teams  Total_Matches
# 0     MI            231
# 1    RCB            226
# 2     DC            224
# 3    KKR            223
# 4   PBKS            218
# 5    CSK            208
# 6     RR            192
# 7    SRH            152
# 8    DCG             75
# 9     PW             46
# 10   RPS             30
# 11    GL             30
# 12    GT             16
# 13   LSG             15
# 14   KTK             14

# %%
win_df = teams_matches
win_df['total_wins']= df['WinningTeam'].value_counts().reset_index()['WinningTeam']
win_df['win_ratio']= round((win_df['total_wins']/win_df['Total_Matches']),2)*100
win_df
# Out:
#    Teams  Total_Matches  total_wins  win_ratio
# 0     MI            231         131       57.0
# 1    RCB            226         121       54.0
# 2     DC            224         114       51.0
# 3    KKR            223         109       49.0
# 4   PBKS            218         103       47.0
# 5    CSK            208         101       49.0
# 6     RR            192          96       50.0
# 7    SRH            152          75       49.0
# 8    DCG             75          29       39.0
# 9     PW             46          15       33.0
# 10   RPS             30          13       43.0
# 11    GL             30          12       40.0
# 12    GT             16          12       75.0
# 13   LSG             15           9       60.0
# 14   KTK             14           6       43.0

# %%
plt.figure(figsize=(15,6.5))
sns.set_style('darkgrid')
wi = sns.barplot(data=win_df, x='win_ratio', y='Teams', ci=False)
wi.set_xticklabels(win_df['win_ratio'].sort_values(), rotation=90, fontdict={'fontsize':10})
plt.show()

# %% [markdown]
# we can see that Gujrat Titans has best winning percentage but Gujrat Titans has low number of matches played. So, overall Mumbai Indians has good winning percentage.

# %% [markdown]
# #### Top 10 Batters that got Player of Match Title

# %%
d1=df['Player_of_Match'].value_counts().reset_index()
d1.set_axis(['Player_of_Match','Count'],axis = 'columns' ,inplace = True)

# %%
d1.head(10)
# Out:
#   Player_of_Match  Count
# 0  AB de Villiers     25
# 1        CH Gayle     22
# 2       RG Sharma     18
# 3       DA Warner     18
# 4        MS Dhoni     17
# 5       YK Pathan     16
# 6       SR Watson     16
# 7        SK Raina     14
# 8      KA Pollard     14
# 9         V Kohli     14

# %%
df['Player_of_Match'].value_counts().reset_index()
# Out:
#               index  Player_of_Match
# 0    AB de Villiers               25
# 1          CH Gayle               22
# 2         RG Sharma               18
# 3         DA Warner               18
# 4          MS Dhoni               17
# ..              ...              ...
# 258    Kartik Tyagi                1
# 259       DJG Sammy                1
# 260      D Padikkal                1
# 261       KK Cooper                1
# 262     MF Maharoof                1
#
# [263 rows x 2 columns]

# %%
player_of_macth_df = df['Player_of_Match'].value_counts().reset_index()
player_of_macth_df.rename(columns={'index':'Player_of_Match','Player_of_Match':'Count'},inplace=True)
top_10_Player_of_match = player_of_macth_df.head(10)

# %%
player_of_macth_df
# Out:
#     Player_of_Match  Count
# 0    AB de Villiers     25
# 1          CH Gayle     22
# 2         RG Sharma     18
# 3         DA Warner     18
# 4          MS Dhoni     17
# ..              ...    ...
# 258    Kartik Tyagi      1
# 259       DJG Sammy      1
# 260      D Padikkal      1
# 261       KK Cooper      1
# 262     MF Maharoof      1
#
# [263 rows x 2 columns]

# %%
plt.figure(figsize=(9,4))
plt.plot(top_10_Player_of_match['Count'], top_10_Player_of_match['Player_of_Match'], 'o-g')

plt.xlabel('Count')
plt.ylabel('Player of Match')

plt.title('Top 10 Player of Match');

# %% [markdown]
# Above analysis show that, with 25 man of the match trophies, **AB de Villiers** has most man of the match in IPL. While **CH Gayle** is in second number who has most man of the match in IPL.

# %% [markdown]
# ## Top 10 IPL hosted cities
# We will analyze the top cities that hosted IPL most time.

# %%
df['City'].value_counts().reset_index()
# Out:
#              index  City
# 0           Mumbai   159
# 1        Bangalore    80
# 2          Kolkata    79
# 3            Delhi    78
# 4          Chennai    67
# 5        Hyderabad    64
# 6       Chandigarh    56
# 7             Pune    51
# 8           Jaipur    47
# 9            Dubai    46
# 10       Abu Dhabi    37
# 11         Sharjah    28
# 12       Ahmedabad    19
# 13          Durban    15
# 14   Visakhapatnam    13
# 15       Centurion    12
# 16          Rajkot    10
# 17          Indore     9
# 18     Navi Mumbai     9
# 19      Dharamsala     9
# 20    Johannesburg     8
# 21  Port Elizabeth     7
# 22       Cape Town     7
# 23         Cuttack     7
# 24          Ranchi     7
# 25          Raipur     6
# 26           Kochi     5
# 27          Kanpur     4
# 28          Nagpur     3
# 29       Kimberley     3
# 30     East London     3
# 31    Bloemfontein     2

# %%
citraw = df['City'].value_counts().reset_index()
citraw.rename(columns={'index':'City','City':'Count'},inplace=True)
top10_city_host = citraw.head(10)
top10_city_host
# Out:
#          City  Count
# 0      Mumbai    159
# 1   Bangalore     80
# 2     Kolkata     79
# 3       Delhi     78
# 4     Chennai     67
# 5   Hyderabad     64
# 6  Chandigarh     56
# 7        Pune     51
# 8      Jaipur     47
# 9       Dubai     46

# %%
plt.figure(figsize=(16,8))
palette_color = sns.color_palette("ch:s=.25,rot=-.25")
sns.barplot(x='Count', y='City',palette = palette_color, data=top10_city_host);
plt.title('Top 10 IPL hosted cities');

# %% [markdown]
# Mumbai hosted maximum matches of Indian Premium League.

# %% [markdown]
# #### Number of Matches hosted in all Seasons

# %%
df["Season"]=pd.DatetimeIndex(df["Date"]).year
matches_in_season=df.groupby(['Season'])['ID'].count().reset_index().rename(columns={'ID':'matches'})
matches_in_season
# Out:
#     Season  matches
# 0     2008       58
# 1     2009       57
# 2     2010       60
# 3     2011       73
# 4     2012       74
# 5     2013       76
# 6     2014       60
# 7     2015       59
# 8     2016       60
# 9     2017       59
# 10    2018       60
# 11    2019       60
# 12    2020       60
# 13    2021       60
# 14    2022       74

# %%
plt.figure(figsize=(12,5))

sns.barplot(x='Season', y='matches', data=matches_in_season);
plt.title('No of total matches per season');

# %% [markdown]
# There is chart that show total number of matches held in each Season of IPL. In 2011,2012,2013 and 2022 IPL season have  number  of total matches greater than other seasons.

# %% [markdown]
# #### Most Time Toss Winning Teams

# %%
df['TossWinner'].value_counts().reset_index()
# Out:
#                           index  TossWinner
# 0                Mumbai Indians         123
# 1         Kolkata Knight Riders         114
# 2           Chennai Super Kings         109
# 3   Royal Challengers Bangalore         105
# 4              Rajasthan Royals          99
# 5                  Punjab Kings          94
# 6              Delhi Daredevils          80
# 7           Sunrisers Hyderabad          74
# 8               Deccan Chargers          43
# 9                Delhi Capitals          36
# 10                Pune Warriors          20
# 11                Gujarat Lions          15
# 12               Gujarat Titans          10
# 13         Kochi Tuskers Kerala           8
# 14         Lucknow Super Giants           7
# 15      Rising Pune Supergiants           7
# 16       Rising Pune Supergiant           6

# %%
most_toss_winner =  df['TossWinner'].value_counts().reset_index()
most_toss_winner.rename(columns = {'index':'TossWinner','TossWinner':'Count'},inplace=True)
most_toss_winner
# Out:
#                      TossWinner  Count
# 0                Mumbai Indians    123
# 1         Kolkata Knight Riders    114
# 2           Chennai Super Kings    109
# 3   Royal Challengers Bangalore    105
# 4              Rajasthan Royals     99
# 5                  Punjab Kings     94
# 6              Delhi Daredevils     80
# 7           Sunrisers Hyderabad     74
# 8               Deccan Chargers     43
# 9                Delhi Capitals     36
# 10                Pune Warriors     20
# 11                Gujarat Lions     15
# 12               Gujarat Titans     10
# 13         Kochi Tuskers Kerala      8
# 14         Lucknow Super Giants      7
# 15      Rising Pune Supergiants      7
# 16       Rising Pune Supergiant      6

# %%
plt.figure(figsize=(16,12))
plt.plot(most_toss_winner['Count'], most_toss_winner['TossWinner'], marker='s', c='r', ls='--', lw=2, ms=10, mew=2, mec='navy')

plt.xlabel('Toss Winner')
plt.ylabel('Count')

plt.title('Most time toss winning teams');

# %% [markdown]
# Toss is the most important thing in the cricket, winning the toss has also impact on match win, we will analyze it later. First we can see that **Mumbai Indians**, **Kolkata Knight Riders** and **Chennai Super Kings** won toss most time in IPL history.

# %% [markdown]
# #### Toss Decision in each Season of IPL

# %%
plt.figure(figsize=(16,6))
color_palette = sns.color_palette("Spectral")
sns.countplot(x='Season', hue='TossDecision', data=df,palette=color_palette,saturation=1)
plt.title('Toss Decision in each Season of IPL');

# %% [markdown]
# In 2016, 2017, 2018, and 2019 most of the teams were field first after winning the toss. But the data show that, in 2020 teams went for bat first after winning toss because in 2013 IPL was held in Dubai, and Dubai stadium's ground and weather conditions suit for bat first.  afetr 2013 teams again chose to field first after winning toss because IPL held again in INDIA.

# %% [markdown]
# #### Asking and Answering Questions

# %% [markdown]
# #### Which Team won greater IPL Trophies?

# %%
# go to MatchNumber Col 
# .loc or .iloc

f1 = (df['MatchNumber']=='Final')
winning_team = df[f1]

# %%
winning_team
# Out:
#           ID          City       Date   Season MatchNumber  \
# 0    1312200     Ahmedabad 2022-05-29     2022       Final
# 74   1254117         Dubai 2021-10-15     2021       Final
# 134  1237181         Dubai 2020-11-10  2020/21       Final
# 194  1181768     Hyderabad 2019-05-12     2019       Final
# 254  1136620        Mumbai 2018-05-27     2018       Final
# 314  1082650     Hyderabad 2017-05-21     2017       Final
# 373   981019     Bangalore 2016-05-29     2016       Final
# 433   829823       Kolkata 2015-05-24     2015       Final
# 492   734049     Bangalore 2014-06-01     2014       Final
# 552   598073       Kolkata 2013-05-26     2013       Final
# 628   548381       Chennai 2012-05-27     2012       Final
# 702   501271       Chennai 2011-05-28     2011       Final
# 775   419165        Mumbai 2010-04-25  2009/10       Final
# 835   392239  Johannesburg 2009-05-24     2009       Final
# 892   336040        Mumbai 2008-06-01  2007/08       Final
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 74           Chennai Super Kings        Kolkata Knight Riders
# 134               Delhi Capitals               Mumbai Indians
# 194               Mumbai Indians          Chennai Super Kings
# 254          Sunrisers Hyderabad          Chennai Super Kings
# 314               Mumbai Indians       Rising Pune Supergiant
# 373  Royal Challengers Bangalore          Sunrisers Hyderabad
# 433               Mumbai Indians          Chennai Super Kings
# 492        Kolkata Knight Riders                 Punjab Kings
# 552          Chennai Super Kings               Mumbai Indians
# 628        Kolkata Knight Riders          Chennai Super Kings
# 702          Chennai Super Kings  Royal Challengers Bangalore
# 775          Chennai Super Kings               Mumbai Indians
# 835  Royal Challengers Bangalore              Deccan Chargers
# 892          Chennai Super Kings             Rajasthan Royals
#
#                                          Venue                   TossWinner  \
# 0             Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 74         Dubai International Cricket Stadium        Kolkata Knight Riders
# 134        Dubai International Cricket Stadium               Delhi Capitals
# 194         Rajiv Gandhi International Stadium               Mumbai Indians
# 254                           Wankhede Stadium          Chennai Super Kings
# 314  Rajiv Gandhi International Stadium, Uppal               Mumbai Indians
# 373                      M Chinnaswamy Stadium          Sunrisers Hyderabad
# 433                               Eden Gardens          Chennai Super Kings
# 492                      M Chinnaswamy Stadium        Kolkata Knight Riders
# 552                               Eden Gardens               Mumbai Indians
# 628            MA Chidambaram Stadium, Chepauk          Chennai Super Kings
# 702            MA Chidambaram Stadium, Chepauk          Chennai Super Kings
# 775                 Dr DY Patil Sports Academy          Chennai Super Kings
# 835                      New Wanderers Stadium  Royal Challengers Bangalore
# 892                 Dr DY Patil Sports Academy             Rajasthan Royals
#
#     TossDecision SuperOver            WinningTeam    WonBy Margin  \
# 0            bat         N         Gujarat Titans  Wickets    7.0
# 74         field         N    Chennai Super Kings     Runs   27.0
# 134          bat         N         Mumbai Indians  Wickets    5.0
# 194          bat         N         Mumbai Indians     Runs    1.0
# 254        field         N    Chennai Super Kings  Wickets    8.0
# 314          bat         N         Mumbai Indians     Runs    1.0
# 373          bat         N    Sunrisers Hyderabad     Runs    8.0
# 433        field         N         Mumbai Indians     Runs   41.0
# 492        field         N  Kolkata Knight Riders  Wickets    3.0
# 552          bat         N         Mumbai Indians     Runs   23.0
# 628          bat         N  Kolkata Knight Riders  Wickets    5.0
# 702          bat         N    Chennai Super Kings     Runs   58.0
# 775          bat         N    Chennai Super Kings     Runs   22.0
# 835        field         N        Deccan Chargers     Runs    6.0
# 892        field         N       Rajasthan Royals  Wickets    3.0
#
#     Player_of_Match                                       Team1Players  \
# 0         HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 74     F du Plessis  ['RD Gaikwad', 'F du Plessis', 'RV Uthappa', '...
# 134        TA Boult  ['MP Stoinis', 'S Dhawan', 'AM Rahane', 'SS Iy...
# 194       JJ Bumrah  ['Q de Kock', 'RG Sharma', 'SA Yadav', 'Ishan ...
# 254       SR Watson  ['SP Goswami', 'S Dhawan', 'KS Williamson', 'S...
# 314       KH Pandya  ['LMP Simmons', 'PA Patel', 'AT Rayudu', 'RG S...
# 373     BCJ Cutting  ['CH Gayle', 'V Kohli', 'AB de Villiers', 'KL ...
# 433       RG Sharma  ['LMP Simmons', 'PA Patel', 'RG Sharma', 'KA P...
# 492       MK Pandey  ['RV Uthappa', 'G Gambhir', 'MK Pandey', 'YK P...
# 552      KA Pollard  ['MEK Hussey', 'M Vijay', 'SK Raina', 'S Badri...
# 628        MS Bisla  ['MS Bisla', 'G Gambhir', 'JH Kallis', 'LR Shu...
# 702         M Vijay  ['MEK Hussey', 'M Vijay', 'MS Dhoni', 'SK Rain...
# 775        SK Raina  ['M Vijay', 'ML Hayden', 'SK Raina', 'S Badrin...
# 835        A Kumble  ['JH Kallis', 'MK Pandey', 'RE van der Merwe',...
# 892       YK Pathan  ['PA Patel', 'S Vidyut', 'SK Raina', 'JA Morke...
#
#                                           Team2Players          Umpire1  \
# 0    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...      CB Gaffaney
# 74   ['Shubman Gill', 'VR Iyer', 'N Rana', 'SP Nari...      Nitin Menon
# 134  ['RG Sharma', 'Q de Kock', 'SA Yadav', 'Ishan ...      CB Gaffaney
# 194  ['F du Plessis', 'SR Watson', 'SK Raina', 'AT ...         IJ Gould
# 254  ['SR Watson', 'F du Plessis', 'SK Raina', 'AT ...        M Erasmus
# 314  ['AM Rahane', 'RA Tripathi', 'SPD Smith', 'MS ...         NJ Llong
# 373  ['DA Warner', 'S Dhawan', 'MC Henriques', 'Yuv...  HDPK Dharmasena
# 433  ['DR Smith', 'MEK Hussey', 'SK Raina', 'MS Dho...  HDPK Dharmasena
# 492  ['V Sehwag', 'M Vohra', 'GJ Bailey', 'WP Saha'...  HDPK Dharmasena
# 552  ['DR Smith', 'AP Tare', 'KD Karthik', 'RG Shar...  HDPK Dharmasena
# 628  ['MEK Hussey', 'M Vijay', 'SK Raina', 'MS Dhon...        BF Bowden
# 702  ['MA Agarwal', 'CH Gayle', 'V Kohli', 'AB de V...        Asad Rauf
# 775  ['S Dhawan', 'SR Tendulkar', 'AM Nayar', 'Harb...      RE Koertzen
# 835  ['AC Gilchrist', 'HH Gibbs', 'TL Suman', 'A Sy...      RE Koertzen
# 892  ['NK Patel', 'SA Asnodkar', 'Kamran Akmal', 'S...        BF Bowden
#
#             Umpire2
# 0       Nitin Menon
# 74   RK Illingworth
# 134     Nitin Menon
# 194     Nitin Menon
# 254          S Ravi
# 314          S Ravi
# 373    BNJ Oxenford
# 433  RK Illingworth
# 492    BNJ Oxenford
# 552      SJA Taufel
# 628      SJA Taufel
# 702      SJA Taufel
# 775      SJA Taufel
# 835      SJA Taufel
# 892     RE Koertzen

# %%
winning_team = winning_team['WinningTeam'].value_counts().reset_index().rename(columns={'index':'Team','WinningTeam':'Total Titles'})

# %%
winning_team = winning_team['WinningTeam'].value_counts().reset_index().rename(columns={'Count':'Total Titles'})

# %%
winning_team
# Out:
#                     Team  Total Titles
# 0         Mumbai Indians             5
# 1    Chennai Super Kings             4
# 2  Kolkata Knight Riders             2
# 3         Gujarat Titans             1
# 4    Sunrisers Hyderabad             1
# 5        Deccan Chargers             1
# 6       Rajasthan Royals             1

# %%
plt.figure(figsize=(6,6))
plt.pie(winning_team['Total Titles'],labels=winning_team['Team'])
plt.show()

# %%
import plotly.express as px

# %%
fig = px.pie(winning_team, values=winning_team['Total Titles'], names=winning_team['Team'],
             color =winning_team['Total Titles'])
fig.update_traces(textposition='inside',
                  textinfo='percent+label',
                  sort=False)
fig.update_layout(width=500, height=550)
fig.show()

# %% [markdown]
# Above chart and data show that Mumbai Indian  gets most time the title of winner of IPL League.

# %% [markdown]
# #### Who is the best wicket taker bowler in IPL history?

# %%
dfb.columns
# Out:
# Index(['ID', 'Innings', 'Overs', 'Ballnumber', 'Batter', 'Bowler',
#        'Non-striker', 'Batsman_run', 'Extra_run', 'Total_run', 'Non_boundary',
#        'IsWicketDelivery', 'BattingTeam'],
#       dtype='object')

# %%
dfb['IsWicketDelivery'].value_counts() # 0 - No wicket ,  1 - wicket
# Out:
# 0    214803
# 1     11151
# Name: IsWicketDelivery, dtype: int64

# %%
### Check the bowlers column 
wicket_takers = dfb.groupby('Bowler').sum().reset_index()

# %%
wt = wicket_takers[['Bowler','IsWicketDelivery']]

# %%
wt.rename(columns={'IsWicketDelivery':'Total_Wickets'},inplace=True)

# %%
wt = wt.sort_values(by='Total_Wickets',ascending=False).head(10).reset_index(drop=True)

# %%
wt
# Out:
#             Bowler  Total_Wickets
# 0         DJ Bravo            207
# 1       SL Malinga            188
# 2         A Mishra            175
# 3         R Ashwin            174
# 4        YS Chahal            172
# 5        SP Narine            171
# 6          B Kumar            165
# 7        PP Chawla            165
# 8  Harbhajan Singh            161
# 9        JJ Bumrah            161

# %%
# Set figure size before plotting
sns.set(rc={'figure.figsize': (20, 8)})

ax = sns.barplot(data=wt, x='Bowler', y='Total_Wickets')

# Add labels on bars
for bar in ax.containers:
    ax.bar_label(bar)

# Rotate x-axis labels vertically
# Axis labels
ax.set_xlabel('Bowler', fontsize=18, fontweight='bold')
ax.set_ylabel('Total Wickets', fontsize=18, fontweight='bold')
plt.xticks(rotation=90)
# Increase font size and make tick labels bold
plt.setp(ax.get_xticklabels(), fontsize=20, fontweight='bold')
plt.setp(ax.get_yticklabels(), fontsize=24, fontweight='bold')
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(16,6))
plt.plot(wt['Bowler'], wt['Total_Wickets'], marker='o', c='r', ls='-.', lw=2, ms=10, mew=2, mec='green')

plt.xlabel('Bowler')
plt.ylabel('Wickets taken')

plt.title('Top 10 wickets tackers');

# %% [markdown]
# > By the above plot and data we can see that **DJ Bravo** is the most wicket taker bowler in IPL history.

# %% [markdown]
# #### What is Toss Decision Ratio in IPL?

# %%
df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'Player_of_Match', 'Team1Players', 'Team2Players',
#        'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
#TossWinner', 'TossDecision'
df['TossWinner'].value_counts()
# Out:
# Mumbai Indians                 123
# Kolkata Knight Riders          114
# Chennai Super Kings            109
# Royal Challengers Bangalore    105
# Rajasthan Royals                99
# Punjab Kings                    94
# Delhi Daredevils                80
# Sunrisers Hyderabad             74
# Deccan Chargers                 43
# Delhi Capitals                  36
# Pune Warriors                   20
# Gujarat Lions                   15
# Gujarat Titans                  10
# Kochi Tuskers Kerala             8
# Lucknow Super Giants             7
# Rising Pune Supergiants          7
# Rising Pune Supergiant           6
# Name: TossWinner, dtype: int64

# %%
total =  df['TossDecision'].value_counts().sum()

# %%
total
# Out:
# 950

# %%
d1 =  df['TossDecision'].value_counts()

# %%
d1 = d1.reset_index().rename(columns={'index':'TossDecision','TossDecision':'count'})

# %%
d1
# Out:
#   TossDecision  count
# 0        field    599
# 1          bat    351

# %%
d1['count'].dtype
# Out:
# dtype('int64')

# %%
d1['Ratio'] = d1['count'].apply(lambda x : round(x/total,2)*100)

# %%
d1
# Out:
#   TossDecision  count  Ratio
# 0        field    599   63.0
# 1          bat    351   37.0

# %%
fig = px.pie(  d1, values=d1['Ratio'], names=d1['TossDecision'])
fig.update_traces(textposition='inside',
                  textinfo='percent+label',
                  sort=False)
fig.update_layout(width=500, height=550)
fig.show()

# %% [markdown]
# In IPL we can see that most of the teams chose to field first after winning toss.

# %% [markdown]
# #### Is win depend on winning toss?

# %%
df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'Player_of_Match', 'Team1Players', 'Team2Players',
#        'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
(df.TossWinner==df.WinningTeam).value_counts()
# Out:
# False    499
# True     451
# dtype: int64

# %%
total = (df.TossWinner==df.WinningTeam).value_counts().sum()

# %%
total
# Out:
# 950

# %%
toss_vs_matchwin = (df.TossWinner==df.WinningTeam).value_counts()
toss_vs_matchwin
# Out:
# False    499
# True     451
# dtype: int64

# %%
tm = toss_vs_matchwin.reset_index().rename(columns={'index':'isTossWinner',0:'count'})

# %%
tm['Percentage'] = round((tm['count']/total)*100,2)
tm

# %%
tm
# Out:
#    isTossWinner  count  Percentage
# 0         False    499       52.53
# 1          True    451       47.47

# %%
fig = px.pie(tm, values=tm['Percentage'], names=['Toss Lost','Toss Won'])
fig.update_traces(textposition='inside',
                  textinfo='percent+label',
                  sort=False)
fig.update_layout(width=500, height=550)
fig.show()

# %% [markdown]
# > Overall toss be a factor to win the matches but remember around 52% times the teams which lost the toss have won the match due to their better performance

# %% [markdown]
# #### Which batsmen have most runs in IPL history?

# %%
highest_run_batsmans=dfb.groupby('Batter').sum().reset_index()
highest_run_batsmans = highest_run_batsmans.sort_values(by='Batsman_run',ascending=False).head(10)
highest_run_batsmans[['Batter','Batsman_run']]
# Out:
#              Batter  Batsman_run
# 569         V Kohli         6634
# 462        S Dhawan         6244
# 130       DA Warner         5883
# 430       RG Sharma         5881
# 493        SK Raina         5536
# 27   AB de Villiers         5181
# 108        CH Gayle         4997
# 339        MS Dhoni         4978
# 452      RV Uthappa         4954
# 256      KD Karthik         4377

# %%
plt.figure(figsize=(12,5))
plt.pie(highest_run_batsmans['Batsman_run'],labels=highest_run_batsmans['Batter'],autopct='%.0f%%')
plt.title('BATSMEN WITH MOST RUNS IN IPL HISTORY')
plt.show()

# %% [markdown]
# > By analyzing data we can see that **V Kholi** has maximum runs in the history of IPL followed by **S Dhawan**, **DA Warner** and **RG Sharma**.

# %% [markdown]
# ### Inferences and Conclusion (Story Telling)
# - We analyzing the IPL dataset by different techniques and by plotting charts. We get the information that Mumbai Indians play most matches than other teams and Mumbai Indians winning ratio is also good. So, we get that Mumbai Indian is most successful team of IPL. We also get that Virat Kholi is the most valuable player of IPL beacause he become most time player of match and he is also a batsmen of most runs in IPL history. And DJ Bravo is most wicket taker bowler in IPL history. We also analyze that most toss winning teams chose to field first and most of the toss winning teams winned up 47% of matches but remaining 53% owned one who lost but even if the team has good player they can make the team to win matches reagardless of toss factor . So, we can say that winnig toss depend on match win.
#
# - In this analysis, we also get that in which season most matches played and which city hosted most matches of IPL. We also find that which team won most time the title of winning IPL and which is the most toss winning team in IPL.
#
# I wish you all will like my project. This Exploratory Data Analysis can be improve and can gives more information by plotting and visulizing different charts.
